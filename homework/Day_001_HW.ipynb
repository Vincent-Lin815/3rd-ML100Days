# %%
## 作業1

import numpy as np
import matplotlib.pyplot as plt

w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101)*5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data') 
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)  ## 那個格子在左上，1就在右上，3在左下
plt.show()

def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y,yp):
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 12.055
# The Mean squared error is 228.688

# %%
## 作業2
1. 你選的這組資料為何重要

我找的資料為車載資通訊系統的一些資料，他之所以這麼重要是因為各式各樣的駕駛情況以及駕駛人數據可以由這個系統的數據而來

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

這些數據是由車上所裝置的Sensor而來

3. 蒐集而來的資料型態為何

收集來的資料大多為一些數值及表格，其他少部分為圖片，影片檔

4. 這組資料想解決的問題如何評估

藉由這些資料，能藉由機器學習得知駕駛人的駕駛情況，進而分析出駕駛者屬於哪種類型(激進，溫和)，並由此進行模型分析，解決不必要的能源消耗問題

# %%
## 作業3
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

自由載客業者的核心問題可能來自於不同地區的車輛分配問題
    
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

資料可由app而來，藉由app統計每位乘客的上車地點及下車地點，以及中間所需的載運時間，跟所花的金錢

3. 蒐集而來的資料型態為何

蒐集來的資料型態可能為結構性資料，依照各項分為多個表格及數值

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

乘客叫車車輛一定是越快來越好，因此根據資料統計出每個地區的日平均載客數，人多的地方理當分配較多的車輛，也可以藉由上車即下車的點進行配對，
讓司機無縫接軌，接到最多的客人
