# %%
num=[]
while True:
    n=int(input())
    if n == -9999:
        break
    num.append(n)
num_tuple=tuple(num)
print(num_tuple)
print('Length:',len(num_tuple))
print('Max:',max(num_tuple))
print('Min:',min(num_tuple))
print('Sum:',sum(num_tuple))
# Out:
# 124
# 45
# 75
# 54
# 68
# 97
# 45
# 78
# -9999
# (124, 45, 75, 54, 68, 97, 45, 78)
# Length: 8
# Max: 124
# Min: 45
# Sum: 586

# %%
tup1=()
tup2=()
print('Create tuple1:')
while True:
    n=eval(input())
    if n == -9999:
        break
    tup1+=(n,)
print('Create tuple2:')
while True:
    m=eval(input())
    if m == -9999:
        break
    tup2+=(m,)

print('Combine tuple before sorting:',tup1+tup2)
list_comb=list(tup1+tup2)
print('Combine list after sorting:',sorted(list_comb))
# Out:
# Create tuple1:
# 12
# 46
# 54
# 78
# 965
# 1
# 5
# 656
# -9999
# Create tuple2:
# 45
# 32
# 12
# 45
# 98
# 74
# -9999
# Combine tuple before sorting: (12, 46, 54, 78, 965, 1, 5, 656, 45, 32, 12, 45, 98, 74)
# Combine list after sorting: [1, 5, 12, 12, 32, 45, 45, 46, 54, 74, 78, 98, 656, 965]

# %%
word=()
while True:
    w1=input()
    if w1=='end':
        break
    word+=(w1,)
print(word)
print(word[0:3])
print(word[-3:])
# Out:
# red
# orange
# rest
# young
# old
# big
# dog
# end
# ('red', 'orange', 'rest', 'young', 'old', 'big', 'dog')
# ('red', 'orange', 'rest')
# ('old', 'big', 'dog')

# %%
num=set()
while True:
    w1=eval(input())
    if w1==-9999:
        break
    num.add(w1)
print('Length:',len(num))
print('Max:',max(num))
print('Min:',min(num))
print('Sum:',sum(num))
# Out:
# 12
# -75
# 45
# 65
# 78
# -45
# -1
# 25
# -9999
# Length: 8
# Max: 78
# Min: -75
# Sum: 104

# %%
def inputData(set10):
    while True:
        a=eval(input())
        if a==-9999:
            break
        set10.add(a)
    return set10

def operation(set11,set12):
    print('set1 | set2=',set11 | set12)
    print('set1 & set2=',set11 & set12)
    print('set1 - set2=',set11 - set12)
    print('set1 ^ set2=',set11 ^ set12)
    
def main():
    print('Input set1 data:')
    set1=set()
    inputData(set1)
    
    print('Input set2 data:')
    set2=set()
    inputData(set2)
    
    print('Set1',set1)
    print('Set2',set2)
    operation(set1,set2)
    
main()
# Out:
# Input set1 data:
# 1
# 2
# 3
# 6
# 4
# 8
# 9
# 5
# -9999
# Input set2 data:
# 5
# 1
# 2
# 9
# 8
# 78
# 54
# -9999
# Set1 {1, 2, 3, 4, 5, 6, 8, 9}
# Set2 {1, 2, 5, 8, 9, 78, 54}
# set1 | set2= {1, 2, 3, 4, 5, 6, 8, 9, 78, 54}
# set1 & set2= {1, 2, 5, 8, 9}
# set1 - set2= {3, 4, 6}
# set1 ^ set2= {3, 4, 6, 78, 54}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.Series(np.random.randn(1000),index=np.arange(1000))
data=data.cumsum()

data=pd.DataFrame(np.random.randn(1000,4),
                 index=np.arange(1000),
                 columns=list('ABCD'))
data=data.cumsum()

ax=data.plot.scatter(x='A',y='B',color='DarkBlue',label='Class1')
data.plot.scatter(x='A',y='C',color='Darkgreen',label='Class 2',ax=ax)
plt.show()
