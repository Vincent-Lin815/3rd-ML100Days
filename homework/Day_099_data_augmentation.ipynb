# %%
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %%
# 此函數會幫我們把多張影像畫成一張多宮格圖
def img_combine(img, ncols=8, size=1, path=False):
    from math import ceil
    import matplotlib.pyplot as plt
    import numpy as np
    nimg = len(img)
    nrows = int(ceil(nimg/ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(ncols*size,nrows*size))
    if nrows == 0:
        return
    elif ncols == 1:
        for r, ax in zip(np.arange(nrows), axes):
            nth=r
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                
            ax.set_axis_off()
    elif nrows == 1:
        for c, ax in zip(np.arange(ncols), axes):
            nth=c
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
            ax.set_axis_off()
    else:
        for r, row in zip(np.arange(nrows), axes):
            for c, ax in zip(np.arange(ncols), row):
                nth=r*ncols+c
                if nth < nimg:
                    ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                ax.set_axis_off()
    plt.show()

# %%
# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# 取前 32 張圖片做視覺化
images = x_train[:32]
img_combine(images)

# %%
# 建立 ImageDataGenerator，並指定我們要做資料增強的數值範圍
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

# %%
# 因為隨機性的關係，所以一樣的圖像再經過一次 generator 後的結果不一定相同
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int"))

# %% [markdown]
# ## 作業

# %% [markdown]
# 請使用 ImageDataGenerator 來進行 Cifar-10 資料集的訓練，並觀察不同的圖像增強方法是否會顯著影響訓練結果

# %%
import keras
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 20 # 訓練的 epochs 數量

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(x_train, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

x_train = x_train/255
x_test = x_test/255
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
#model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

#fit with image without augmentation
model.fit(x_train, y_train,
          epochs=epochs,batch_size=batch_size,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
# plot
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

#print the score
score = model.evaluate(x_test, y_test, verbose=0)
print('Total loss',score[0])
print('Total score', score[1])
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_57 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_85 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_86 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_87 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_88 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_89 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_90 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 70s 1ms/step - loss: 1.7638 - accuracy: 0.3616 - val_loss: 1.3715 - val_accuracy: 0.5005
# Epoch 2/20
# 50000/50000 [==============================] - 71s 1ms/step - loss: 1.3225 - accuracy: 0.5272 - val_loss: 1.1248 - val_accuracy: 0.6036
# Epoch 3/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 1.1312 - accuracy: 0.6010 - val_loss: 1.0099 - val_accuracy: 0.6451
# Epoch 4/20
# 50000/50000 [==============================] - 66s 1ms/step - loss: 1.0000 - accuracy: 0.6495 - val_loss: 1.0035 - val_accuracy: 0.6483
# Epoch 5/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.9081 - accuracy: 0.6823 - val_loss: 0.8630 - val_accuracy: 0.7021
# Epoch 6/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.8287 - accuracy: 0.7106 - val_loss: 0.8151 - val_accuracy: 0.7171
# Epoch 7/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.7805 - accuracy: 0.7300 - val_loss: 0.7993 - val_accuracy: 0.7255
# Epoch 8/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.7406 - accuracy: 0.7433 - val_loss: 0.7531 - val_accuracy: 0.7435
# Epoch 9/20
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.7039 - accuracy: 0.7560 - val_loss: 0.7246 - val_accuracy: 0.7572
# Epoch 10/20
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.6741 - accuracy: 0.7663 - val_loss: 0.7674 - val_accuracy: 0.7453
# Epoch 11/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6583 - accuracy: 0.7732 - val_loss: 0.6802 - val_accuracy: 0.7697
# Epoch 12/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6475 - accuracy: 0.7792 - val_loss: 0.7260 - val_accuracy: 0.7591
# Epoch 13/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6338 - accuracy: 0.7852 - val_loss: 0.7511 - val_accuracy: 0.7505
# Epoch 14/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6302 - accuracy: 0.7843 - val_loss: 0.7048 - val_accuracy: 0.7698
# Epoch 15/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6231 - accuracy: 0.7883 - val_loss: 0.6876 - val_accuracy: 0.7802
# Epoch 16/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6220 - accuracy: 0.7914 - val_loss: 0.6746 - val_accuracy: 0.7858
# Epoch 17/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6140 - accuracy: 0.7942 - val_loss: 0.6767 - val_accuracy: 0.7760
# Epoch 18/20
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.6158 - accuracy: 0.7939 - val_loss: 0.8501 - val_accuracy: 0.7572
# Epoch 19/20
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6153 - accuracy: 0.7941 - val_loss: 0.7010 - val_accuracy: 0.7721
# Epoch 20/20
# 50000/50000 [==============================] - 71s 1ms/step - loss: 0.6228 - accuracy: 0.7934 - val_loss: 0.8932 - val_accuracy: 0.7623
# Total loss 0.8931694880485535
# Total score 0.7623000144958496

# %%
#model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

#fit with image after augmentation
model.fit_generator(data_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch = x_train.shape[0] // batch_size, # x_train.shape[0]為'train samples' ;  ## It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

# plot
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

#print the score
score = model.evaluate(x_test, y_test, verbose=0)
print('Total loss',score[0])
print('Total score', score[1])
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_61 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_91 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_92 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_93 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_94 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_95 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_96 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 390/390 [==============================] - 70s 179ms/step - loss: 1.9271 - accuracy: 0.2945 - val_loss: 1.5337 - val_accuracy: 0.4306
# Epoch 2/20
# 390/390 [==============================] - 70s 179ms/step - loss: 1.6034 - accuracy: 0.4219 - val_loss: 1.3234 - val_accuracy: 0.5245
# Epoch 3/20
# 390/390 [==============================] - 70s 180ms/step - loss: 1.4488 - accuracy: 0.4791 - val_loss: 1.2599 - val_accuracy: 0.5469
# Epoch 4/20
# 390/390 [==============================] - 72s 184ms/step - loss: 1.3591 - accuracy: 0.5126 - val_loss: 1.0662 - val_accuracy: 0.6187
# Epoch 5/20
# 390/390 [==============================] - 74s 190ms/step - loss: 1.2900 - accuracy: 0.5379 - val_loss: 1.2159 - val_accuracy: 0.5818
# Epoch 6/20
# 390/390 [==============================] - 72s 185ms/step - loss: 1.2327 - accuracy: 0.5614 - val_loss: 1.1369 - val_accuracy: 0.6131
# Epoch 7/20
# 390/390 [==============================] - 74s 189ms/step - loss: 1.1871 - accuracy: 0.5823 - val_loss: 1.0638 - val_accuracy: 0.6281
# Epoch 8/20
# 390/390 [==============================] - 74s 189ms/step - loss: 1.1522 - accuracy: 0.5936 - val_loss: 0.9364 - val_accuracy: 0.6643
# Epoch 9/20
# 390/390 [==============================] - 71s 182ms/step - loss: 1.1327 - accuracy: 0.6039 - val_loss: 1.0987 - val_accuracy: 0.6245
# Epoch 10/20
# 390/390 [==============================] - 71s 182ms/step - loss: 1.1050 - accuracy: 0.6096 - val_loss: 0.9765 - val_accuracy: 0.6777
# Epoch 11/20
# 390/390 [==============================] - 78s 199ms/step - loss: 1.0856 - accuracy: 0.6202 - val_loss: 0.8390 - val_accuracy: 0.7076
# Epoch 12/20
# 390/390 [==============================] - 75s 192ms/step - loss: 1.0682 - accuracy: 0.6271 - val_loss: 0.8488 - val_accuracy: 0.7074
# Epoch 13/20
# 390/390 [==============================] - 72s 184ms/step - loss: 1.0542 - accuracy: 0.6326 - val_loss: 0.8390 - val_accuracy: 0.7071
# Epoch 14/20
# 390/390 [==============================] - 81s 207ms/step - loss: 1.0388 - accuracy: 0.6405 - val_loss: 0.8249 - val_accuracy: 0.7146
# Epoch 15/20
# 390/390 [==============================] - 72s 186ms/step - loss: 1.0262 - accuracy: 0.6434 - val_loss: 1.0138 - val_accuracy: 0.6686
# Epoch 16/20
# 390/390 [==============================] - 77s 197ms/step - loss: 1.0270 - accuracy: 0.6460 - val_loss: 0.7961 - val_accuracy: 0.7321
# Epoch 17/20
# 390/390 [==============================] - 73s 187ms/step - loss: 1.0115 - accuracy: 0.6503 - val_loss: 0.9214 - val_accuracy: 0.6934
# Epoch 18/20
# 390/390 [==============================] - 72s 184ms/step - loss: 1.0107 - accuracy: 0.6528 - val_loss: 0.8616 - val_accuracy: 0.7094
# Epoch 19/20
# 390/390 [==============================] - 72s 185ms/step - loss: 1.0063 - accuracy: 0.6543 - val_loss: 0.9521 - val_accuracy: 0.6722
# Epoch 20/20
# 390/390 [==============================] - 72s 184ms/step - loss: 1.0025 - accuracy: 0.6567 - val_loss: 0.9627 - val_accuracy: 0.6857
# Total loss 0.9626810335159302
# Total score 0.685699999332428
